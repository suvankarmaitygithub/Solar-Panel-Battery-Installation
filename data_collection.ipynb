# %%
import pandas as pd
import numpy as np

# Simulate data
np.random.seed(42)
data = pd.DataFrame({
    'household_id': range(1, 101),
    'grid_reliability': np.random.uniform(0.8, 1.0, 100),  # 0 to 1 scale
    'avg_power_outage_duration': np.random.uniform(0, 5, 100),  # in hours per month
    'peak_power_requirement': np.random.uniform(2, 10, 100),  # in kW
    'off_peak_power_requirement': np.random.uniform(1, 5, 100),  # in kW
    'solar_generation_capacity': np.random.uniform(3, 12, 100),  # in kW
    'excess_electricity': np.random.uniform(0, 6, 100),  # in kWh
    'battery_capacity': np.random.choice([5, 10, 15], 100),  # in kWh
    'battery_type': np.random.choice(['Lithium-ion', 'Lead-acid'], 100),
    'purchase_battery': np.random.choice([0, 1], 100)  # 0: No, 1: Yes
})

data.to_csv('prosumer_data.csv', index=False)

# %%
pd.read_csv('prosumer_data.csv')
# Out:
#     household_id  grid_reliability  avg_power_outage_duration  \
# 0              1          0.874908                   0.157146
# 1              2          0.990143                   3.182052
# 2              3          0.946399                   1.571780
# 3              4          0.919732                   2.542853
# 4              5          0.831204                   4.537832
# ..           ...               ...                        ...
# 95            96          0.898759                   1.746048
# 96            97          0.904547                   3.629778
# 97            98          0.885508                   4.485551
# 98            99          0.805084                   4.435432
# 99           100          0.821578                   3.899378
#
#     peak_power_requirement  off_peak_power_requirement  \
# 0                 7.136253                    1.206727
# 1                 2.673120                    3.125419
# ...

# %% [markdown]
# # We can also get the excess electricity as a difference between the peak and solar generation capacity.
